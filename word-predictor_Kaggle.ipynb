# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/kaggle/input/quotes-dataset/qoute_dataset.csv')
df
# Out:
#                                                   quote           Author
# 0     “The world as we have created it is a process ...  Albert Einstein
# 1     “It is our choices, Harry, that show what we t...     J.K. Rowling
# 2     “There are only two ways to live your life. On...  Albert Einstein
# 3     “The person, be it gentleman or lady, who has ...      Jane Austen
# 4     “Imperfection is beauty, madness is genius and...   Marilyn Monroe
# ...                                                 ...              ...
# 3033      The past beats inside me like a second heart.   John Banville,
# 3034  Damn, Claire. Warn a guy before you do a face-...    Rachel Caine,
# 3035  Can you be a girl for a few seconds?""I'm alwa...   Veronica Roth,
# 3036  That's what fiction is for. It's for getting a...      Tim O'Brien
# 3037  If we have no peace, it is because we have for...    Mother Teresa
#
# [3038 rows x 2 columns]

# %%
qts = df['quote']
qts.head()
# Out:
# 0    “The world as we have created it is a process ...
# 1    “It is our choices, Harry, that show what we t...
# 2    “There are only two ways to live your life. On...
# 3    “The person, be it gentleman or lady, who has ...
# 4    “Imperfection is beauty, madness is genius and...
# Name: quote, dtype: object

# %% [markdown]
# ## Steps
# Tokenization
#
# Vectorization
#
# Embedding

# %% [markdown]
# ##  Preprocessing

# %%
qts = qts.str.lower()

# %%
import string

translator = str.maketrans('','',string.punctuation)

# %%
qts = qts.apply(lambda x:x.translate(translator))
qts.head()
# Out:
# 0    “the world as we have created it is a process ...
# 1    “it is our choices harry that show what we tru...
# 2    “there are only two ways to live your life one...
# 3    “the person be it gentleman or lady who has no...
# 4    “imperfection is beauty madness is genius and ...
# Name: quote, dtype: object

# %% [markdown]
# ## Tokenization

# %%
qts[0]
# Out:
# '“the world as we have created it is a process of our thinking it cannot be changed without changing our thinking”'

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

# using Tokenizer , not .split

vocab_size=10000

token = Tokenizer(num_words=vocab_size)
token.fit_on_texts(qts)
# Out:
# 2026-02-04 08:37:29.892303: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770194249.917518     666 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770194249.925451     666 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770194249.945359     666 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770194249.945397     666 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770194249.945400     666 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1770194249.945403     666 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
word_index = token.word_index
print(len(word_index))
# Out:
# 8978

# %%
list(word_index.items())[:10]
# Out:
# [('the', 1),
#  ('you', 2),
#  ('to', 3),
#  ('and', 4),
#  ('a', 5),
#  ('i', 6),
#  ('is', 7),
#  ('of', 8),
#  ('that', 9),
#  ('it', 10)]

# %%
sequence = token.texts_to_sequences(qts)

# %%
print(f'Sentence : {qts[0]}\n to Vector : {sequence[0]}')
# Out:
# Sentence : “the world as we have created it is a process of our thinking it cannot be changed without changing our thinking”
#  to Vector : [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8, 70, 293, 10, 145, 12, 809, 104, 752, 70, 2461]

# %% [markdown]
# ### Making X,y from sentence tokens...

# %%
X = []
y = []

for seq in sequence:
    for i in range(1,len(seq)):
        
        input_seq = seq[:i]
        output_seq = seq[i]
        
        X.append(input_seq)
        y.append(output_seq)

# %%
X[:20]
# Out:
# [[713],
#  [713, 62],
#  [713, 62, 29],
#  [713, 62, 29, 19],
#  [713, 62, 29, 19, 16],
#  [713, 62, 29, 19, 16, 946],
#  [713, 62, 29, 19, 16, 946, 10],
#  [713, 62, 29, 19, 16, 946, 10, 7],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8, 70],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8, 70, 293],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8, 70, 293, 10],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8, 70, 293, 10, 145],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8, 70, 293, 10, 145, 12],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8, 70, 293, 10, 145, 12, 809],
#  [713, 62, 29, 19, 16, 946, 10, 7, 5, 1156, 8, 70, 293, 10, 145, 12, 809, 104],
#  [713,
#   62,
#   29,
#   19,
#   16,
#   946,
#   10,
#   7,
#   5,
#   1156,
#   8,
#   70,
#   293,
#   10,
#   145,
#   12,
#   809,
#   104,
#   752],
#  [713,
#   62,
#   29,
#   19,
#   16,
#   946,
#   10,
#   7,
#   5,
#   1156,
#   8,
#   70,
#   293,
#   10,
#   145,
#   12,
#   809,
#   104,
#   752,
#   70]]

# %%
len(X)
# Out:
# 85271

# %%
len(y)
# Out:
# 85271

# %% [markdown]
# ## Padding

# %%
max_len = max(len(x) for x in X)
max_len
# Out:
# 745

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_pad = pad_sequences( X,
    maxlen=max_len,
    padding='pre',)
X_pad
# Out:
# array([[   0,    0,    0, ...,    0,    0,  713],
#        [   0,    0,    0, ...,    0,  713,   62],
#        [   0,    0,    0, ...,  713,   62,   29],
#        ...,
#        [   0,    0,    0, ...,    9,   19, 1125],
#        [   0,    0,    0, ...,   19, 1125,    3],
#        [   0,    0,    0, ..., 1125,    3,  169]], dtype=int32)

# %%
X_pad.shape
# Out:
# (85271, 745)

# %%
y = np.array(y)
y
# Out:
# array([ 62,  29,  19, ...,   3, 169, 101])

# %% [markdown]
# ## making sparse y,OneHot enc

# %%
from tensorflow.keras.utils import to_categorical

y_enc = to_categorical(y,num_classes=vocab_size)

# %%
y_enc.shape
# Out:
# (85271, 10000)

# %% [markdown]
# ## Embedding & Model built using LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers

# %%
embed_dim = 50
rnn_units = 128

# %%
lstm = Sequential([
    layers.Embedding(input_dim = vocab_size, output_dim = embed_dim),

    layers.LSTM(units = rnn_units), #units=128

    layers.Dense(units=vocab_size, activation='softmax')
])
# Out:
# I0000 00:00:1770194254.918340     666 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1770194254.920345     666 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
lstm.compile(optimizer = 'adam',
            loss = 'categorical_crossentropy',
            metrics = ['accuracy'])

# %%
lstm.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history_lstm = lstm.fit(x = X_pad, y = y_enc, batch_size=128 , epochs=100, validation_split=0.1)
# Out:
# Epoch 1/100
# I0000 00:00:1770194268.433510     726 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 35s 52ms/step - accuracy: 0.0351 - loss: 7.1159 - val_accuracy: 0.0448 - val_loss: 6.6767
# Epoch 2/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - accuracy: 0.0556 - loss: 6.3540 - val_accuracy: 0.0652 - val_loss: 6.5595
# Epoch 3/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.0777 - loss: 6.0678 - val_accuracy: 0.0879 - val_loss: 6.4533
# Epoch 4/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.0999 - loss: 5.8175 - val_accuracy: 0.0944 - val_loss: 6.4416
# Epoch 5/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - accuracy: 0.1070 - loss: 5.6318 - val_accuracy: 0.1001 - val_loss: 6.4216
# Epoch 6/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.1169 - loss: 5.4719 - val_accuracy: 0.1051 - val_loss: 6.4389
# Epoch 7/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.1260 - loss: 5.3148 - val_accuracy: 0.1082 - val_loss: 6.4636
# Epoch 8/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - accuracy: 0.1342 - loss: 5.1609 - val_accuracy: 0.1075 - val_loss: 6.4948
# Epoch 9/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.1420 - loss: 5.0283 - val_accuracy: 0.1074 - val_loss: 6.5341
# Epoch 10/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0
100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6408 - loss: 1.6507 - val_accuracy: 0.0829 - val_loss: 10.3518
# Epoch 72/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6436 - loss: 1.6289 - val_accuracy: 0.0844 - val_loss: 10.4201
# Epoch 73/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6462 - loss: 1.6196 - val_accuracy: 0.0811 - val_loss: 10.4521
# Epoch 74/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6512 - loss: 1.5939 - val_accuracy: 0.0822 - val_loss: 10.5006
# Epoch 75/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6539 - loss: 1.5802 - val_accuracy: 0.0818 - val_loss: 10.5676
# Epoch 76/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6558 - loss: 1.5704 - val_accuracy: 0.0806 - val_loss: 10.6010
# Epoch 77/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6625 - loss: 1.5434 - val_accuracy: 0.0802 - val_loss: 10.6311
# Epoch 78/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6668 - loss: 1.5256 - val_accuracy: 0.0783 - val_loss: 10.6961
# Epoch 79/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6689 - loss: 1.5126 - val_accuracy: 0.0790 - val_loss: 10.7413
# Epoch 80/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6739 - loss: 1.4907 - val_accuracy: 0.0807 - val_loss: 10.7882
# Epoch 81/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6763 - loss: 1.4672 - val_accuracy: 0.0815 - val_loss: 10.8450
# Epoch 82/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6828 - loss: 1.4555 - val_accuracy: 0.0792 - val_loss: 10.8901
# Epoch 83/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6829 - loss: 1.4435 - val_accuracy: 0.0783 - val_loss: 10.9398
# Epoch 84/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6876 - loss: 1.4216 - val_accuracy: 0.0786 - val_loss: 10.9849
# Epoch 85/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6877 - loss: 1.4072 - val_accuracy: 0.0806 - val_loss: 11.0500
# Epoch 86/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.6906 - loss: 1.4105 - val_accuracy: 0.0804 - val_loss: 11.0949
# Epoch 87/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.6979 - loss: 1.3806 - val_accuracy: 0.0818 - val_loss: 11.1502
# Epoch 88/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.6996 - loss: 1.3608 - val_accuracy: 0.0807 - val_loss: 11.1741
# Epoch 89/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7015 - loss: 1.3649 - val_accuracy: 0.0776 - val_loss: 11.2186
# Epoch 90/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.7078 - loss: 1.3303 - val_accuracy: 0.0776 - val_loss: 11.2653
# Epoch 91/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 51ms/step - accuracy: 0.7117 - loss: 1.3207 - val_accuracy: 0.0781 - val_loss: 11.3178
# Epoch 92/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7117 - loss: 1.3088 - val_accuracy: 0.0795 - val_loss: 11.3572
# Epoch 93/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7153 - loss: 1.2938 - val_accuracy: 0.0779 - val_loss: 11.4100
# Epoch 94/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7193 - loss: 1.2819 - val_accuracy: 0.0781 - val_loss: 11.4268
# Epoch 95/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7170 - loss: 1.2778 - val_accuracy: 0.0779 - val_loss: 11.4740
# Epoch 96/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7240 - loss: 1.2554 - val_accuracy: 0.0794 - val_loss: 11.5482
# Epoch 97/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7248 - loss: 1.2532 - val_accuracy: 0.0792 - val_loss: 11.5877
# Epoch 98/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7319 - loss: 1.2163 - val_accuracy: 0.0807 - val_loss: 11.6066
# Epoch 99/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 30s 50ms/step - accuracy: 0.7291 - loss: 1.2261 - val_accuracy: 0.0768 - val_loss: 11.6497
# Epoch 100/100
# 600/600 ━━━━━━━━━━━━━━━━━━━━ 31s 51ms/step - accuracy: 0.7346 - loss: 1.2116 - val_accuracy: 0.0777 - val_loss: 11.7039

# %%
lstm.save("lstm_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import pickle

with open("tokenizer.pkl", "wb") as f:
    pickle.dump(token, f)
